# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

import datetime

import xgboost as xgb

# %%
df_train = pd.read_csv('data/trainData.csv')
df_sample = pd.read_csv('data/sample.csv')

df_train.index = df_train['日期']

df_train.info()
df_sample.info()
# df_sample['地区'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16305 entries, 2014-01-01 to 2016-12-31
# Data columns (total 5 columns):
# 日期    16305 non-null object
# 地区    16305 non-null object
# 价格    16305 non-null float64
# 数量    16305 non-null float64
# 均重    16305 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 764.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1305 entries, 0 to 1304
# Data columns (total 3 columns):
# ﻿日期    1305 non-null object
# 地区     1305 non-null object
# 价格     1305 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 30.7+ KB

# %%
Area = set(df_sample['地区'].values)
Area = list(Area)

# %%
def getLineModel(AreaName):
    df_train_GD = df_train[df_train['地区'] == AreaName]
    year = 2016
    x = []
    y = []

    for i in range(1,4):
#         print(i)
        for d in range(1,32):
            if i == 2 and d > 28:
                continue
            
            tmp = []
            if d < 10: 
                s = str(year)+'-0'+str(i)+'-0'+str(d)
            else: 
                s = str(year)+'-0'+str(i)+'-'+str(d)
    #         print(s)
            if len(df_train_GD[df_train_GD.index == s]['价格'].values) == 0:
                if len(y) == 0:
                    y.append(df_train_GD[df_train_GD.index == '2015-01-01']['价格'].values[0])
                else:
                    y.append(y[len(y)-1])

            else:
                y.append(df_train_GD[df_train_GD.index == s]['价格'].values[0])

            # 得到前一周的价格列表
            curtime = datetime.datetime.strptime(s,'%Y-%m-%d')
            lasttime = curtime - datetime.timedelta(days = 6)
            # 日期到字符串
            lasttime = datetime.datetime.strftime(lasttime,'%Y-%m-%d')
            curtime = datetime.datetime.strftime(curtime,'%Y-%m-%d')
            tmp.extend(list(df_train_GD[lasttime:curtime]['价格'].values))

            if len(tmp)<7:
                tmp.extend(tmp[len(tmp)-7:])

    #         print(len(tmp))
            # 得到前两年对应时间的前5天，后五天
            if d < 10: 
                s = str(year-2)+'-0'+str(i)+'-0'+str(d)
            else: 
                s = str(year-2)+'-0'+str(i)+'-'+str(d)
            curtime = datetime.datetime.strptime(s,'%Y-%m-%d')
            lasttime = curtime - datetime.timedelta(days = 4)
            nexttime = curtime + datetime.timedelta(days = 4)

            curtime = datetime.datetime.strftime(curtime,'%Y-%m-%d')
            lasttime = datetime.datetime.strftime(lasttime,'%Y-%m-%d')
            nexttime = datetime.datetime.strftime(nexttime,'%Y-%m-%d')

            tmp.extend(list(df_train_GD[lasttime:curtime]['价格'].values))
            tmp.extend(list(df_train_GD[curtime:nexttime]['价格'].values))

            if len(tmp) < 17:
                tmp.extend(tmp[len(tmp)-17:])

            # 得到前一年对应时间的前5天，后五天
            if d < 10: 
                s = str(year-1)+'-0'+str(i)+'-0'+str(d)
            else: 
                s = str(year-1)+'-0'+str(i)+'-'+str(d)
            curtime = datetime.datetime.strptime(s,'%Y-%m-%d')
            lasttime = curtime - datetime.timedelta(days = 4)
            nexttime = curtime + datetime.timedelta(days = 4)

            curtime = datetime.datetime.strftime(curtime,'%Y-%m-%d')
            lasttime = datetime.datetime.strftime(lasttime,'%Y-%m-%d')
            nexttime = datetime.datetime.strftime(nexttime,'%Y-%m-%d')

            tmp.extend(list(df_train_GD[lasttime:curtime]['价格'].values))
            tmp.extend(list(df_train_GD[curtime:nexttime]['价格'].values))

            if len(tmp) < 27:
                tmp.extend(tmp[len(tmp)-27:])

    #         print(len(tmp))
            x.append(tmp)

    #         print(s)

    # 得到参数
    x = np.array(x)
    y = np.array(y)

    print(x.shape)
    print(len(y))
    
#     from sklearn import linear_model

#     regr = linear_model.LinearRegression()
#     regr.fit(x, y)

        
    xlf = xgb.XGBRegressor(max_depth=10, 
                        learning_rate=0.1, 
                        n_estimators=10, 
                        silent=True, 
                        objective='reg:linear', 
                        nthread=-1, 
                        gamma=0,
                        min_child_weight=1, 
                        max_delta_step=0, 
                        subsample=0.85, 
                        colsample_bytree=0.7, 
                        colsample_bylevel=1, 
                        reg_alpha=0, 
                        reg_lambda=1, 
                        scale_pos_weight=1, 
                        seed=1440, 
                        missing=None)

    xlf.fit(x, y)

    
    
    return xlf

# %%
def Predicted(AreaName,regr):
    df_train_GD = df_train[df_train['地区'] == AreaName]
    year = 2017
    x = []
    y = []

    for i in range(1,4):
        for d in range(1,32):
            if i == 2 and d > 28: 
                continue
            tmp = []
            if d < 10: 
                ts = str(year)+'-0'+str(i)+'-0'+str(d)
            else: 
                ts = str(year)+'-0'+str(i)+'-'+str(d)
            # 得到前一周的价格列表
            curtime = datetime.datetime.strptime(ts,'%Y-%m-%d')
            lasttime = curtime - datetime.timedelta(days = 6)
            # 日期到字符串
            lasttime = datetime.datetime.strftime(lasttime,'%Y-%m-%d')
            curtime = datetime.datetime.strftime(curtime,'%Y-%m-%d')
            tmp.extend(list(df_train_GD[lasttime:curtime]['价格'].values))

            if len(tmp)<7:
                tmp.extend(tmp[len(tmp)-7:])

    #         print(len(tmp))
            # 得到前两年对应时间的前5天，后五天
            if d < 10: 
                s = str(year-2)+'-0'+str(i)+'-0'+str(d)
            else: 
                s = str(year-2)+'-0'+str(i)+'-'+str(d)
            curtime = datetime.datetime.strptime(s,'%Y-%m-%d')
            lasttime = curtime - datetime.timedelta(days = 4)
            nexttime = curtime + datetime.timedelta(days = 4)

            curtime = datetime.datetime.strftime(curtime,'%Y-%m-%d')
            lasttime = datetime.datetime.strftime(lasttime,'%Y-%m-%d')
            nexttime = datetime.datetime.strftime(nexttime,'%Y-%m-%d')

            tmp.extend(list(df_train_GD[lasttime:curtime]['价格'].values))
            tmp.extend(list(df_train_GD[curtime:nexttime]['价格'].values))

    #         print(df_train_GD[curtime:nexttime])

            if len(tmp) < 17:
                tmp.extend(tmp[len(tmp)-17:])



            # 得到前一年对应时间的前5天，后五天
            if d < 10: 
                s = str(year-1)+'-0'+str(i)+'-0'+str(d)
            else: 
                s = str(year-1)+'-0'+str(i)+'-'+str(d)
            curtime = datetime.datetime.strptime(s,'%Y-%m-%d')
            lasttime = curtime - datetime.timedelta(days = 4)
            nexttime = curtime + datetime.timedelta(days = 4)

            curtime = datetime.datetime.strftime(curtime,'%Y-%m-%d')
            lasttime = datetime.datetime.strftime(lasttime,'%Y-%m-%d')
            nexttime = datetime.datetime.strftime(nexttime,'%Y-%m-%d')

            tmp.extend(list(df_train_GD[lasttime:curtime]['价格'].values))
            tmp.extend(list(df_train_GD[curtime:nexttime]['价格'].values))

    #         print(df_train_GD[lasttime:curtime])
    #         print(df_train_GD[curtime:nexttime])

            if len(tmp) < 27:
                tmp.extend(tmp[len(tmp)-27:])

    #         print(tmp)
            tmp = np.array(tmp)


            y_ = regr.predict([tmp])
            
            print(y_)
            
            t = pd.DataFrame({'日期':ts, '地区':AreaName,'价格':y_,'数量':None,'均重':None})
            t.index = t['日期']
    #         print(t)

            df_train_GD = df_train_GD.append(t)
            
#         print(len(df_train_GD['2017-01-01':'2017-04-01']))
            
    return df_train_GD['2017-01-01':'2017-03-31']
# Out:
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x7fe3574fdd68>>
# Traceback (most recent call last):
#   File "/home/xiaoran/anaconda3/lib/python3.5/site-packages/xgboost/core.py", line 324, in __del__
#     _check_call(_LIB.XGDMatrixFree(self.handle))
# AttributeError: 'DMatrix' object has no attribute 'handle'

# %%
len(Area)
# Out:
# 15

# %%
df_ans = pd.DataFrame()

for i in range(len(Area)):
    regrModel = getLineModel(Area[i])
    df_ans = df_ans.append(Predicted(Area[i],regrModel))
# Out:
# (90, 27)
# 90
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# [ 3.25120234]
# (90, 27)
# 90
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# [ 3.79125857]
# (90, 27)
# 90
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# [ 2.98010755]
# (90, 27)
# 90
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.40483832]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.40483832]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.40483832]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.40483832]
# [ 3.30916333]
# [ 3.40483832]
# [ 3.40483832]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.30916333]
# [ 3.40483832]
# [ 3.30916333]
# [ 3.40483832]
# [ 3.40483832]
# [ 3.30916333]
# [ 3.40483832]
# [ 3.40483832]
# [ 3.40483832]
# [ 3.40483832]
# [ 3.40483832]
# [ 3.40483832]
# [ 3.40483832]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# [ 3.49099016]
# Exception ignored in: <bound method DMatrix.__del__ of <xgboost.core.DMatrix object at 0x7fe357cdcfd0>>
# Traceback (most recent call last):
#   File "/home/xiaoran/anaconda3/lib/python3.5/site-packages/xgboost/core.py", line 324, in __del__
#     _check_call(_LIB.XGDMatrixFree(self.handle))
# AttributeError: 'DMatrix' object has no attribute 'handle'
# [ 3.49099016]
# [ 3.49099016]
# (90, 27)
# 90
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# [ 3.4303081]
# (90, 27)
# 90
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# [ 3.2850039]
# (90, 27)
# 90
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# [ 3.2015841]
# (90, 27)
# 90
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# [ 4.21244669]
# (90, 27)
# 90
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# [ 3.94306159]
# (90, 27)
# 90
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# [ 3.22648048]
# (90, 27)
# 90
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# [ 3.20031142]
# (90, 27)
# 90
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# [ 3.87556124]
# (90, 27)
# 90
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# [ 3.64918447]
# (90, 27)
# 90
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# [ 3.76248717]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-84337f89695a> in <module>()
#       2
#       3 for i in range(len(Area)):
# ----> 4     regrModel = getLineModel(Area[i])
#       5     df_ans = df_ans.append(Predicted(Area[i],regrModel))
#
# <ipython-input-22-58264ee62c90> in getLineModel(AreaName)
#      32             lasttime = datetime.datetime.strftime(lasttime,'%Y-%m-%d')
#      33             curtime = datetime.datetime.strftime(curtime,'%Y-%m-%d')
# ---> 34             tmp.extend(list(df_train_GD[lasttime:curtime]['价格'].values))
#      35
#      36             if len(tmp)<7:
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1985         indexer = convert_to_index_sliceable(self, key)
#    1986         if indexer is not None:
# -> 1987             return self._getitem_slice(indexer)
#    1988
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_slice(self, key)
#    2012
#    2013     def _getitem_slice(self, key):
# -> 2014         return self._slice(key, axis=0)
#    2015
#    2016     def _getitem_array(self, key):
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in _slice(self, slobj, axis, kind)
#    1452         """
#    1453         axis = self._get_block_manager_axis(axis)
# -> 1454         result = self._constructor(self._data.get_slice(slobj, axis=axis))
#    1455         result = result.__finalize__(self)
#    1456
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in get_slice(self, slobj, axis)
#    3095
#    3096         new_axes = list(self.axes)
# -> 3097         new_axes[axis] = new_axes[axis][slobj]
#    3098
#    3099         bm = self.__class__(new_blocks, new_axes, do_integrity_check=False,
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in __getitem__(self, key)
#    1267             # This case is separated from the conditional above to avoid
#    1268             # pessimization of basic indexing.
# -> 1269             return promote(getitem(key))
#    1270
#    1271         if is_bool_indexer(key):
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in _shallow_copy(self, values, **kwargs)
#     350         attributes = self._get_attributes_dict()
#     351         attributes.update(kwargs)
# --> 352         return self._simple_new(values, **attributes)
#     353
#     354     def _shallow_copy_with_infer(self, values=None, **kwargs):
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in _simple_new(cls, values, name, dtype, **kwargs)
#     327         result._data = values
#     328         result.name = name
# --> 329         for k, v in compat.iteritems(kwargs):
#     330             setattr(result, k, v)
#     331         return result._reset_identity()
#
# KeyboardInterrupt:

# %%
df_ans.info()
df_ans = df_ans.sort(['日期','地区'])[['地区','价格']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrame
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: '日期'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-35db58efd812> in <module>()
#       1 df_ans.info()
# ----> 2 df_ans = df_ans.sort(['日期','地区'])[['地区','价格']]
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in sort(self, columns, axis, ascending, inplace, kind, na_position, **kwargs)
#    3223         return self.sort_values(by=columns, axis=axis, ascending=ascending,
#    3224                                 inplace=inplace, kind=kind,
# -> 3225                                 na_position=na_position)
#    3226
#    3227     @Appender(_shared_docs['sort_index'] % _shared_doc_kwargs)
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3137             keys = []
#    3138             for x in by:
# -> 3139                 k = self[x].values
#    3140                 if k.ndim == 2:
#    3141                     raise ValueError('Cannot sort by duplicate column %s' %
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: '日期'

# %%
df_ans
# Out:
#             地区         价格
# 日期
# 2017-01-01  云南   5.110000
# 2017-01-01  四川   4.710000
# 2017-01-01  安徽   4.024164
# 2017-01-01  山东   4.240000
# 2017-01-01  广东   4.950000
# 2017-01-01  广西   5.492626
# 2017-01-01  江苏   3.920000
# 2017-01-01  江西   4.200000
# 2017-01-01  浙江   3.810000
# 2017-01-01  海南   5.940000
# 2017-01-01  湖北   4.075633
# 2017-01-01  湖南   4.177518
# 2017-01-01  福建   4.590000
# 2017-01-01  贵州   4.950000
# 2017-01-01  重庆   4.550000
# 2017-01-02  云南   5.110000
# 2017-01-02  四川   4.710000
# 2017-01-02  安徽   4.040542
# 2017-01-02  山东   4.240000
# 2017-01-02  广东   4.950000
# 2017-01-02  广西   5.661080
# 2017-01-02  江苏   3.920000
# 2017-01-02  江西   4.200000
# 2017-01-02  浙江   3.810000
# 2017-01-02  海南   5.940000
# 2017-01-02  湖北   4.118265
# 2017-01-02  湖南   4.376142
# 2017-01-02  福建   4.590000
# 2017-01-02  贵州   4.950000
# 2017-01-02  重庆   4.550000
# ...         ..        ...
# 2017-03-30  云南   5.110000
# 2017-03-30  四川   4.710000
# 2017-03-30  安徽   5.023209
# 2017-03-30  山东   4.240000
# 2017-03-30  广东   4.950000
# 2017-03-30  广西  12.717156
# 2017-03-30  江苏   3.920000
# 2017-03-30  江西   4.200000
# 2017-03-30  浙江   3.810000
# 2017-03-30  海南   5.940000
# 2017-03-30  湖北   7.996889
# 2017-03-30  湖南   6.101649
# 2017-03-30  福建   4.590000
# 2017-03-30  贵州   4.950000
# 2017-03-30  重庆   4.550000
# 2017-03-31  云南   5.110000
# 2017-03-31  四川   4.710000
# 2017-03-31  安徽   4.988210
# 2017-03-31  山东   4.240000
# 2017-03-31  广东   4.950000
# 2017-03-31  广西  12.742615
# 2017-03-31  江苏   3.920000
# 2017-03-31  江西   4.200000
# 2017-03-31  浙江   3.810000
# 2017-03-31  海南   5.940000
# 2017-03-31  湖北   8.020071
# 2017-03-31  湖南   6.028521
# 2017-03-31  福建   4.590000
# 2017-03-31  贵州   4.950000
# 2017-03-31  重庆   4.550000
#
# [1350 rows x 2 columns]

# %%
df_ans.to_csv('data/result.csv')

# %%
# 结合预测结果，与2014-2016年对应的时间取均值
df_ans1 = df_train['2014-01-01':'2014-03-31'][['日期','地区','价格']].sort(['日期','地区'])
df_ans2 = df_train['2015-01-01':'2015-03-31'][['日期','地区','价格']].sort(['日期','地区'])
df_ans3 = df_train['2016-01-01':'2016-03-31'][['日期','地区','价格']].sort(['日期','地区'])
# Out:
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
# /home/xiaoran/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
df_ans.info()
df_ans1.info()
df_ans2.info()
df_ans3.info()

df_ans1.groupby('日期').count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1350 entries, 2017-01-01 to 2017-03-31
# Data columns (total 2 columns):
# 地区    1350 non-null object
# 价格    1350 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 31.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1304 entries, 2014-01-01 to 2014-03-31
# Data columns (total 3 columns):
# 日期    1304 non-null object
# 地区    1304 non-null object
# 价格    1304 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 40.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1307 entries, 2015-01-01 to 2015-03-31
# Data columns (total 3 columns):
# 日期    1307 non-null object
# 地区    1307 non-null object
# 价格    1307 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 40.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1320 entries, 2016-01-01 to 2016-03-31
# Data columns (total 3 columns):
# 日期    1320 non-null object
# 地区    1320 non-null object
# 价格    1320 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 41.2+ KB
#             地区  价格
# 日期
# 2014-01-01  15  15
# 2014-01-02  15  15
# 2014-01-03  15  15
# 2014-01-04  15  15
# 2014-01-05  15  15
# 2014-01-06  15  15
# 2014-01-07  15  15
# 2014-01-08  15  15
# 2014-01-09  15  15
# 2014-01-10  15  15
# 2014-01-11  15  15
# 2014-01-12  15  15
# 2014-01-13  15  15
# 2014-01-14  15  15
# 2014-01-15  15  15
# 2014-01-16  15  15
# 2014-01-17  15  15
# 2014-01-18  15  15
# 2014-01-19  15  15
# 2014-01-20  15  15
# 2014-01-21  15  15
# 2014-01-22  15  15
# 2014-01-23  15  15
# 2014-01-24  15  15
# 2014-01-25  15  15
# 2014-01-26  15  15
# 2014-01-27  15  15
# 2014-01-28  14  14
# 2014-01-29  12  12
# 2014-01-30   4   4
# ...         ..  ..
# 2014-03-02  15  15
# 2014-03-03  15  15
# 2014-03-04  15  15
# 2014-03-05  15  15
# 2014-03-06  15  15
# 2014-03-07  15  15
# 2014-03-08  15  15
# 2014-03-09  15  15
# 2014-03-10  15  15
# 2014-03-11  15  15
# 2014-03-12  15  15
# 2014-03-13  15  15
# 2014-03-14  15  15
# 2014-03-15  15  15
# 2014-03-16  15  15
# 2014-03-17  15  15
# 2014-03-18  15  15
# 2014-03-19  15  15
# 2014-03-20  15  15
# 2014-03-21  15  15
# 2014-03-22  15  15
# 2014-03-23  15  15
# 2014-03-24  15  15
# 2014-03-25  15  15
# 2014-03-26  15  15
# 2014-03-27  15  15
# 2014-03-28  15  15
# 2014-03-29  15  15
# 2014-03-30  15  15
# 2014-03-31  15  15
#
# [89 rows x 2 columns]
